# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_csv('openfoodfacts_export.csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df=pd.DataFrame(data)
product_df=product_df[['code','product_name_de','brands','categories', 'labels']]
product_df=product_df[product_df['product_name_de'].notna()]
product_df.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df=product_df.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df.replace(np. nan,'',regex=True)
# Out:
#                 product_code  \
# 0              4104420240315
# 1              4016249238155
# 2              4016249173906
# 3              4104420018747
# 4              4104420136540
# 5              4061458089616
# 6              4260655550206
# 8              4104420242005
# 9              4104420241886
# 10             4104420022386
# 12             4104420186828
# 13             4104420031869
# 15             4104420219588
# 16             9173087094864
# 17             4104420225534
# 18             4104420226616
# 19             4104420082281
# 20             4104420146600
# 21             4104420083660
# 22             4104420220232
# 23             4104420240407
# 25             4104420034341
# 26             4056114005345
# 27             4104420016484
# 28             4104420145986
# 29             4104420145962
# 31                  40045122
# 32             4016249172350
# 33             4016249108519
# 34             4044889004106
# 35             4104420131385
# ...

# %%
data=pd.read_csv('openfoodfacts_export (2).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df2=pd.DataFrame(data)
product_df2=product_df2[['code','product_name_de','brands','categories', 'labels']]
product_df2=product_df2[product_df2['product_name_de'].notna()]
product_df2.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df2=product_df2.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df2.replace(np. nan,'',regex=True)
product_df2
# Out:
#     product_code                                     product_name  \
# 0  8014806030026                                      Tomatenmark
# 1  4260180540086                                       Hühnertopf
# 2  4012344902076                               Currywurst im Glas
# 3  4003301081972       Spätburgunder Roséwein feinherb Pfalz 2021
# 4  4062073003742  Riesling Grauer Burgunder Weißwein trocken 2020
# 5  4003301081996          Bio Dornfelder Rotwein Rheinhessen 2020
# 6         187886                                 denns Nuss Müsli
# 7  4021851101452                         Denn Reederei Soja Drink
#
#                                     brand  \
# 0                         Denn's, Dennree
# 1                                   Denns
# 2                               Bio denns
# 3  Meisterstück denns, Meisterstück denns
# 4                      Meisterstück denns
# 5                      Meisterstück denns
# 6                          Denns, Dennree
# ...

# %%
data=pd.read_csv('openfoodfacts_export (3).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df3=pd.DataFrame(data)
product_df3
product_df3=product_df3[['code','product_name_de','brands','categories', 'labels']]
product_df3=product_df3[product_df3['product_name_de'].notna()]
product_df3.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df3=product_df3.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df3.replace(np. nan,'',regex=True)
# Out:
#      product_code                                       product_name  \
# 0   4260655550206                       Bio-Aufstrich Paprika pikant
# 1   4016249198879                    aufs Brot: Süßkartoffel kurkuma
# 2   4016249172350             Pflanzlicher Brotaufstrich mit Avocado
# 3   4016249108519        Hof-Gemüse Champignon Zwiebel Brotaufstrich
# 11  4016249155216  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 12  4016249155223  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 13  4016249316020  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 14  4016249316051  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 15  4016249315894  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 16  4016249315863  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 17  4260655551159             DipDip Hurra Süßkartoffel orientalisch
# 18  4260655550220                     Bio-aufstrich tomate & kräuter
# 19  4260655550237                               Rettergut bio-hummus
# ...

# %%
data=pd.read_csv('openfoodfacts_export (4).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df4=pd.DataFrame(data)
product_df4=product_df4[['code','product_name_de','brands','categories', 'labels']]
product_df4=product_df4[product_df4['product_name_de'].notna()]
product_df4.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df4=product_df4.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df4.replace(np. nan,'',regex=True)
# Out:
#       product_code                                product_name  \
# 0    5411188112709                                 Mandeldrink
# 2    5411188119098                         Natur mit Kokosnuss
# 3    5411188110835                             Mandel Original
# 4    5411188124689                           Hafer ohne Zucker
# 5    5411188125808      Produit fermenté au soja saveur mangue
# 6    5411188118961  Nature aux Amandes - Végétal soja & amande
# 7    5411188118121                           Natur ohne Zucker
# 8    5411188115472                        Soya  Milch Original
# 9    5411188116592                         Kokosnuss mit Reiss
# 10   5411188128588                      Skyr Style ohne Zucker
# 11   5411188115366                              Hafer Original
# 12   5411188134985                          Not Milk 3,5% Fett
# 13   5411188124269                             Natur mit Hafer
# 14   5411188102809                          Blueberry soya pot
# ...

# %%
data=pd.read_csv('openfoodfacts_export (6).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df6=pd.DataFrame(data)
product_df6=product_df6[['code','product_name_de','brands','categories', 'labels']]
product_df6=product_df6[product_df6['product_name_de'].notna()]
product_df6.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df6=product_df6.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df6.replace(np. nan,'',regex=True)
# Out:
#      product_code                       product_name  \
# 1   4015637010588                       Gold Nuggets
# 2   4015637826417                 Wunder Brod (Brot)
# 3   4015637842837                         Apfel Mark
# 4   4015637006475                       Haferflocken
# 5   4015637009025           Schnelle Brötchen Saaten
# 8   4015637010564                 Bratwurst VeggiMix
# 9   4015637821399                       Gemüseburger
# 10  4015637824697                   Kichererbsenmehl
# 11  4015637824604                     Mehlmix Kuchen
# 12  4015637007250                 Haferbrot Vollkorn
# 13  4015637823003               PizzaTeig Glutenfrei
# 14  4015637821337                    Hartweizengrieß
# 15  4015637827391              Schneller Apfelkuchen
# 16  4015637824055                    Mais Paniermehl
# 17  4015637823836                Obstkuchen Rührteig
# 18  4015637827131                         Mandelmehl
# 19  4015637835013  Müzli Früchtetraum Hafer ungesüßt
# ...

# %%
data=pd.read_csv('openfoodfacts_export (7).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df7=pd.DataFrame(data)
product_df7=product_df7[['code','product_name_de','brands','categories', 'labels']]
product_df7=product_df7[product_df7['product_name_de'].notna()]
product_df7.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df7=product_df7.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df7.replace(np. nan,'',regex=True)
# Out:
#       product_code                                       product_name  \
# 0    4000540000658                       Hafer Flocken ( Kernig ) Bio
# 1    4000540000641                                  Bio Hafer Flocken
# 2    4000540031881                                       Schoko Müsli
# 3    4000540003468                              Müsli Knusper Klassik
# 4    4000540001457                         Hafer-Müsli - Rainbow Love
# 5    4000540003185                  Hafer-Müsli - Crunchy Peanut Choc
# 6    4000540003130               Hafer-Müsli - Crunchy Choc-Choc-Choc
# 7    4000540000108                                       Haferflocken
# 8    4000540091069                        Knusprige Haferfleks Schoko
# 9         64404554           Kölln Schmelzflocken 4. Monat ohne Milch
# 10   4000540000177                                       Haferflocken
# 11   4000540000306          Echte Kölln Kernige Vollkorn-Haferflocken
# ...

# %%
data=pd.read_csv('openfoodfacts_export (8).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df8=pd.DataFrame(data)
product_df8=product_df8[['code','product_name_de','brands','categories', 'labels']]
product_df8=product_df8[product_df8['product_name_de'].notna()]
product_df8.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df8=product_df8.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df8.replace(np. nan,'',regex=True)
# Out:
#      product_code                                       product_name  \
# 0   7300400129206                Wasa Tasty Snacks Sea Salt Crackers
# 1   7300400126229                 Delicate Crisp Rosemary & Sea Salt
# 2   7300400482684                               Wasa Milch & Joghurt
# 3   7300400482172                    Brot Knäckebrot Mohn & Meersalz
# 4   7300400481465                                      Sesam gourmet
# 5   7300400126465                                  Knäckebrot Roggen
# 6   7300400129640                      Knäckebrot - Roggen Sauerteig
# 7   7300400114714                                Knäckebrot Vollkorn
# 8   7300400481830                     Knäckebrot Sesamöl und Seasalt
# 10  7300400481823                      classic Knäckebrot Glutenfrei
# 11  7300400127288                                           Proteine
# 12  7300400127387                              Cheese Tomato & Basil
# 13  7300400482219                   Tasty snacks french herbs rounds
# ...

# %%
data=pd.read_csv('openfoodfacts_export9.csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df9=pd.DataFrame(data)
product_df9=product_df9[['code','product_name_de','brands','categories', 'labels']]
product_df9=product_df9[product_df9['product_name_de'].notna()]
product_df9.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df9=product_df9.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df9.replace(np. nan,'',regex=True)
product_df9
# Out:
#      product_code                                product_name  \
# 0   8008698041208                                     Fusilli
# 1   8008698018460                              Laugenbrötchen
# 2   8008698004869    Mehl Mix C Kuchen und Kekse, glutenfrei,
# 3   8008698004838                   Mehl Brot-Mix, glutenfrei
# 4   8008698033210                      Pizza Base, glutenfrei
# 5   8008698028315                         Landbrot glutenfrei
# 6   8008698027400                      Meisterbäckers Classic
# 7   8008698038734                        Meisterbäckers Vital
# 9   8008698027424                        Sterbäckers Mehrkorn
# 10  8008698026953                       Panino Laugenbrötchen
# 11  2110583004659                                  Ofenbraten
# 12  8008698004548                              Digestive Choc
# 13  8008698004098             Bontà d'italia lasagne all'uovo
# 14  8008698004753                                  Paniermehl
# ...

# %%
data=pd.read_csv('openfoodfacts_export (10).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df10=pd.DataFrame(data)
product_df10=product_df10[['code','product_name_de','brands','categories', 'labels']]
product_df10=product_df10[product_df10['product_name_de'].notna()]
product_df10.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df10=product_df10.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df10.replace(np. nan,'',regex=True)
product_df10
# Out:
#      product_code                                  product_name  \
# 0   7394376617157                     Aufstrich Gurke&Knoblauch
# 1   7394376619267                            Havermilch Vanille
# 2   7394376615894                     Oatly Haferdrink Original
# 3   7394376616419                       Haferdrink Orange Mango
# 4   7394376617904                   Oatly Hafer Barista Edition
# 5   7394376616129                                    Haferdrink
# 6   7394376618895                              OATLY Strawberry
# 7   7394376616136                           Hafer/Haver - Kakao
# 8   7394376616501                    Haferdrink Barista-Edition
# 9   7394376616952                                 Hafer Cuisine
# 10  7394376616907                           Organic Mocha Latte
# 11  7394376665097                             Oat-ly Hafermilch
# 12  7394376617911                Aufstrich Kräuter der Provence
# 13  7394376617140                  Aufstrich Tomate & Basilikum
# ...

# %%
data=pd.read_csv('openfoodfacts_export (12).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df12=pd.DataFrame(data)
product_df12=product_df12[['code','product_name_de','brands','categories', 'labels']]
product_df12=product_df12[product_df12['product_name_de'].notna()]
product_df12.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df12=product_df12.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df12.replace(np. nan,'',regex=True)
product_df12
# Out:
#      product_code                                       product_name  \
# 0   5038862231718                                      Smoothie Plus
# 1   5038862230209                           Energise  Super Smoothie
# 2   5038862001540                        Smoothie Plus Vitaminbündel
# 3   5038862239400                                      Vitaminbündel
# 4   5038862430043                                     Multi Mix gelb
# 5   5038862431279                  Direktsaft Clementine + Mandarine
# 6   5038862433921                              Innocent wonder green
# 8   5038862435345                                         Blue Break
# 9   5038862234252                                 Obstgarten Erdbeer
# 12  5038862235372                      Smoothie Traube Banane Cassis
# 13  5038862230230                      Smoothie Pfirsich Apfel Mango
# 14  5038862237901                         Ananas, Banane & Kokosnuss
# 15  5038862439121        Blaubeere, Apfel, Johannisbeere & Cranberry
# ...

# %%
data=pd.read_csv('openfoodfacts_export (13).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df13=pd.DataFrame(data)
product_df13=product_df13[['code','product_name_de','brands','categories', 'labels']]
product_df13=product_df13[product_df13['product_name_de'].notna()]
product_df13.rename(columns={'code':'product_code','product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df13=product_df13.reindex(['product_code','product_name','brand', 'category','description'], axis=1)
product_df13.replace(np. nan,'',regex=True)
product_df13
# Out:
#       product_code                                       product_name  \
# 0    8033224183152                                Getrocknete Tomaten
# 1    4021851556467                                      Cherrytomaten
# 2    8014806030026                                        Tomatenmark
# 3    4021851005101                                        Vanille Eis
# 4    4021851546680                                           Farfalle
# 5    4021851626979                                       Schokolinsen
# 6    4021851591291                                       Kichererbsen
# 7    4021851021385                                           Brokkoli
# 8    4021851455746                        Himbeeren gefriergetrocknet
# 9    4021851819562                                               TOFU
# 10   4021851798072                               Tofu mit Röstzwiebel
# 11   4021851455739                        Erdbeeren gefriergetrocknet
# ...

# %%
merged_df = pd.concat([product_df, product_df3,product_df4,product_df6,product_df7,product_df8,product_df9,product_df10,product_df12,product_df13])
pd.set_option("display.max_rows", 2262)
merged_df.index = np.arange(1, len(merged_df) + 1)
merged_df['store_id'] = np.random.randint(0, 88, merged_df.shape[0])
merged_df['quantity'] = np.random.randint(0, 20, merged_df.shape[0])
merged_df = merged_df[['store_id', 'product_code', 'product_name', 'quantity', 'brand', 'category', 'description']]
merged_df.fillna('', inplace=True)
