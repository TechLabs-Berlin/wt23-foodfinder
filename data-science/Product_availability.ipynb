# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_csv('openfoodfacts_export.csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df=pd.DataFrame(data)
product_df=product_df[['product_name_de','brands','categories', 'labels']]
product_df=product_df[product_df['product_name_de'].notna()]
product_df.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df=product_df.reindex(['product_name','brand', 'category','description'], axis=1)
product_df.replace(np. nan,'',regex=True)
# Out:
#                                            product_name  \
# 0                                          Joghurt mild
# 1                              Saatenliebe Mohn Avocado
# 2                     Linsen-Aufstrich Rote Linse Chili
# 3                                         Dinkel Flakes
# 4                                        Basis Porridge
# 5                                            Backpulver
# 6                          Bio-Aufstrich Paprika pikant
# 8                 Alnatura Leinsamen pflaume und dattel
# 9                                  Leinsamen geschrotet
# 10                                Leinsamen, Geschrotet
# 12                                            Bolognese
# 13                    Vegetarische Bolognese mit Gemüse
# 15                                          Kokos Drink
# 16                                         Räucher Tofu
# 17                                        Hafer flocken
# 18                                        Hafer Flocken
# ...

# %%
data=pd.read_csv('openfoodfacts_export (2).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df2=pd.DataFrame(data)
product_df2=product_df2[['product_name_de','brands','categories', 'labels']]
product_df2=product_df2[product_df2['product_name_de'].notna()]
product_df2.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df2=product_df2.reindex(['product_name','brand', 'category','description'], axis=1)
product_df2.replace(np. nan,'',regex=True)
product_df2
# Out:
#                                       product_name  \
# 0                                      Tomatenmark
# 1                                       Hühnertopf
# 2                               Currywurst im Glas
# 3       Spätburgunder Roséwein feinherb Pfalz 2021
# 4  Riesling Grauer Burgunder Weißwein trocken 2020
# 5          Bio Dornfelder Rotwein Rheinhessen 2020
# 6                                 denns Nuss Müsli
# 7                         Denn Reederei Soja Drink
#
#                                     brand  \
# 0                         Denn's, Dennree
# 1                                   Denns
# 2                               Bio denns
# 3  Meisterstück denns, Meisterstück denns
# 4                      Meisterstück denns
# 5                      Meisterstück denns
# 6                          Denns, Dennree
# 7                                  denree
#
#                                             category  \
# 0  Pflanzliche Lebensmittel und Getränke, Pflanzl...
# ...

# %%
data=pd.read_csv('openfoodfacts_export (3).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df3=pd.DataFrame(data)
product_df3
product_df3=product_df3[['product_name_de','brands','categories', 'labels']]
product_df3=product_df3[product_df3['product_name_de'].notna()]
product_df3.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df3=product_df3.reindex(['product_name','brand', 'category','description'], axis=1)
product_df3.replace(np. nan,'',regex=True)
# Out:
#                                          product_name  \
# 0                        Bio-Aufstrich Paprika pikant
# 1                     aufs Brot: Süßkartoffel kurkuma
# 2              Pflanzlicher Brotaufstrich mit Avocado
# 3         Hof-Gemüse Champignon Zwiebel Brotaufstrich
# 11  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 12  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 13  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 14  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 15  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 16  Pflanzlicher Brotaufstrich mit roten Linden, W...
# 17             DipDip Hurra Süßkartoffel orientalisch
# 18                     Bio-aufstrich tomate & kräuter
# 19                               Rettergut bio-hummus
# 20             Bio-aufstrich rote Beete & Meerrettich
# 21    DipDip Hurra Bio-Aufstrich Tomate & Grillgemüse
# 22                        Protein RAWba Salty Caramel
# ...

# %%
data=pd.read_csv('openfoodfacts_export (4).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df4=pd.DataFrame(data)
product_df4=product_df4[['product_name_de','brands','categories', 'labels']]
product_df4=product_df4[product_df4['product_name_de'].notna()]
product_df4.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df4=product_df4.reindex(['product_name','brand', 'category','description'], axis=1)
product_df4.replace(np. nan,'',regex=True)
# Out:
#                                    product_name               brand  \
# 0                                   Mandeldrink               Alpro
# 2                           Natur mit Kokosnuss               Alpro
# 3                               Mandel Original               Alpro
# 4                             Hafer ohne Zucker               Alpro
# 5        Produit fermenté au soja saveur mangue               Alpro
# 6    Nature aux Amandes - Végétal soja & amande               Alpro
# 7                             Natur ohne Zucker               Alpro
# 8                          Soya  Milch Original               Alpro
# 9                           Kokosnuss mit Reiss               alpro
# 10                       Skyr Style ohne Zucker               Alpro
# 11                               Hafer Original               Alpro
# 12                           Not Milk 3,5% Fett               Alpro
# 13                              Natur mit Hafer               Alpro
# ...

# %%
data=pd.read_csv('openfoodfacts_export (6).csv',sep='\t')
pd.set_option("display.max_rows", 1314)
product_df6=pd.DataFrame(data)
product_df6=product_df6[['product_name_de','brands','categories', 'labels']]
product_df6=product_df6[product_df6['product_name_de'].notna()]
product_df6.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df6=product_df6.reindex(['product_name','brand', 'category','description'], axis=1)
product_df6.replace(np. nan,'',regex=True)
# Out:
#                          product_name                       brand  \
# 1                        Gold Nuggets                    bauckhof
# 2                  Wunder Brod (Brot)                    Bauckhof
# 3                          Apfel Mark         Bauckhof, Bauck Hof
# 4                        Haferflocken                    Bauckhof
# 5            Schnelle Brötchen Saaten         Bauckhof, Bauck Hof
# 8                  Bratwurst VeggiMix                    Bauckhof
# 9                        Gemüseburger         Bauck Hof, Bauckhof
# 10                   Kichererbsenmehl                    Bauckhof
# 11                     Mehlmix Kuchen                    Bauckhof
# 12                 Haferbrot Vollkorn         Bauckhof, Bauck Hof
# 13               PizzaTeig Glutenfrei         Bauck Hof, Bauckhof
# 14                    Hartweizengrieß                    Bauckhof
# 15              Schneller Apfelkuchen         Bauck Hof, Bauckhof
# ...

# %%
data=pd.read_csv('openfoodfacts_export (7).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df7=pd.DataFrame(data)
product_df7=product_df7[['product_name_de','brands','categories', 'labels']]
product_df7=product_df7[product_df7['product_name_de'].notna()]
product_df7.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df7=product_df7.reindex(['product_name','brand', 'category','description'], axis=1)
product_df7.replace(np. nan,'',regex=True)
# Out:
#                                           product_name  \
# 0                         Hafer Flocken ( Kernig ) Bio
# 1                                    Bio Hafer Flocken
# 2                                         Schoko Müsli
# 3                                Müsli Knusper Klassik
# 4                           Hafer-Müsli - Rainbow Love
# 5                    Hafer-Müsli - Crunchy Peanut Choc
# 6                 Hafer-Müsli - Crunchy Choc-Choc-Choc
# 7                                         Haferflocken
# 8                          Knusprige Haferfleks Schoko
# 9             Kölln Schmelzflocken 4. Monat ohne Milch
# 10                                        Haferflocken
# 11           Echte Kölln Kernige Vollkorn-Haferflocken
# 12                                  Zauberfleks Schoko
# 13                           Multikorn Flocken, Kernig
# 14                  Vollkorn Haferfleks Knusper-Schoko
# 15   Knusper Vollkorn-Müsli mit 5 % Schokoladenblät...
# ...

# %%
data=pd.read_csv('openfoodfacts_export (8).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df8=pd.DataFrame(data)
product_df8=product_df8[['product_name_de','brands','categories', 'labels']]
product_df8=product_df8[product_df8['product_name_de'].notna()]
product_df8.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df8=product_df8.reindex(['product_name','brand', 'category','description'], axis=1)
product_df8.replace(np. nan,'',regex=True)
# Out:
#                                          product_name  \
# 0                 Wasa Tasty Snacks Sea Salt Crackers
# 1                  Delicate Crisp Rosemary & Sea Salt
# 2                                Wasa Milch & Joghurt
# 3                     Brot Knäckebrot Mohn & Meersalz
# 4                                       Sesam gourmet
# 5                                   Knäckebrot Roggen
# 6                       Knäckebrot - Roggen Sauerteig
# 7                                 Knäckebrot Vollkorn
# 8                      Knäckebrot Sesamöl und Seasalt
# 10                      classic Knäckebrot Glutenfrei
# 11                                           Proteine
# 12                              Cheese Tomato & Basil
# 13                   Tasty snacks french herbs rounds
# 15                               Brot Knäcke Rustikal
# 16             wasa Tasty Snacks Sesame & Salt rounds
# 17                                Taste Bites Pumpkin
# ...

# %%
data=pd.read_csv('openfoodfacts_export9.csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df9=pd.DataFrame(data)
product_df9=product_df9[['product_name_de','brands','categories', 'labels']]
product_df9=product_df9[product_df9['product_name_de'].notna()]
product_df9.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df9=product_df9.reindex(['product_name','brand', 'category','description'], axis=1)
product_df9.replace(np. nan,'',regex=True)
product_df9
# Out:
#                                   product_name  \
# 0                                      Fusilli
# 1                               Laugenbrötchen
# 2     Mehl Mix C Kuchen und Kekse, glutenfrei,
# 3                    Mehl Brot-Mix, glutenfrei
# 4                       Pizza Base, glutenfrei
# 5                          Landbrot glutenfrei
# 6                       Meisterbäckers Classic
# 7                         Meisterbäckers Vital
# 9                         Sterbäckers Mehrkorn
# 10                       Panino Laugenbrötchen
# 11                                  Ofenbraten
# 12                              Digestive Choc
# 13             Bontà d'italia lasagne all'uovo
# 14                                  Paniermehl
# 15                      Bontà d'italia fusilli
# 16                             Curvies Paprika
# 17           Glutenfrei Pâtes Spaghetti  Schär
# 18  Pain campagnard aux graines de lin et chia
# 19                                    Zwieback
# ...

# %%
data=pd.read_csv('openfoodfacts_export (10).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df10=pd.DataFrame(data)
product_df10=product_df10[['product_name_de','brands','categories', 'labels']]
product_df10=product_df10[product_df10['product_name_de'].notna()]
product_df10.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df10=product_df10.reindex(['product_name','brand', 'category','description'], axis=1)
product_df10.replace(np. nan,'',regex=True)
product_df10
# Out:
#                                     product_name                      brand  \
# 0                      Aufstrich Gurke&Knoblauch                      oatly
# 1                             Havermilch Vanille                      Oatly
# 2                      Oatly Haferdrink Original                      Oatly
# 3                        Haferdrink Orange Mango                      Oatly
# 4                    Oatly Hafer Barista Edition         The Original Oatly
# 5                                     Haferdrink                      Oatly
# 6                               OATLY Strawberry                      Oatly
# 7                            Hafer/Haver - Kakao                      Oatly
# 8                     Haferdrink Barista-Edition                      OATLY
# 9                                  Hafer Cuisine                      Oatly
# 10                           Organic Mocha Latte                      Oatly
# ...

# %%
data=pd.read_csv('openfoodfacts_export (12).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df12=pd.DataFrame(data)
product_df12=product_df12[['product_name_de','brands','categories', 'labels']]
product_df12=product_df12[product_df12['product_name_de'].notna()]
product_df12.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df12=product_df12.reindex(['product_name','brand', 'category','description'], axis=1)
product_df12.replace(np. nan,'',regex=True)
product_df12
# Out:
#                                          product_name  \
# 0                                       Smoothie Plus
# 1                            Energise  Super Smoothie
# 2                         Smoothie Plus Vitaminbündel
# 3                                       Vitaminbündel
# 4                                      Multi Mix gelb
# 5                   Direktsaft Clementine + Mandarine
# 6                               Innocent wonder green
# 8                                          Blue Break
# 9                                  Obstgarten Erdbeer
# 12                      Smoothie Traube Banane Cassis
# 13                      Smoothie Pfirsich Apfel Mango
# 14                         Ananas, Banane & Kokosnuss
# 15        Blaubeere, Apfel, Johannisbeere & Cranberry
# 16                          Direktsaft Apfel & Beeren
# 17                                      Multi Mix rot
# 18        Blaubeere, Apfel, Johannisbeere & Cranberry
# ...

# %%
data=pd.read_csv('openfoodfacts_export (13).csv',sep='\t')
pd.set_option("display.max_rows", 2000)
product_df13=pd.DataFrame(data)
product_df13=product_df13[['product_name_de','brands','categories', 'labels']]
product_df13=product_df13[product_df13['product_name_de'].notna()]
product_df13.rename(columns={'product_name_de': 'product_name','brands':'brand','categories':'category','labels':'description'}, inplace=True)
product_df13=product_df13.reindex(['product_name','brand', 'category','description'], axis=1)
product_df13.replace(np. nan,'',regex=True)
product_df13
# Out:
#                                           product_name  \
# 0                                  Getrocknete Tomaten
# 1                                        Cherrytomaten
# 2                                          Tomatenmark
# 3                                          Vanille Eis
# 4                                             Farfalle
# 5                                         Schokolinsen
# 6                                         Kichererbsen
# 7                                             Brokkoli
# 8                          Himbeeren gefriergetrocknet
# 9                                                 TOFU
# 10                                Tofu mit Röstzwiebel
# 11                         Erdbeeren gefriergetrocknet
# 12                                             Fusilli
# 13                                             Fusilli
# 14                                             Fusilli
# 15                                                Mais
# ...

# %%
merged_df = pd.concat([product_df, product_df3,product_df4,product_df6,product_df7,product_df8,product_df9,product_df10,product_df12,product_df13])
pd.set_option("display.max_rows", 2262)
merged_df.index = np.arange(1, len(merged_df) + 1)
merged_df['store_id'] = np.random.randint(0, 88, merged_df.shape[0])
merged_df['quantity'] = np.random.randint(0, 20, merged_df.shape[0])
merged_df = merged_df[['store_id', 'product_name', 'quantity', 'brand', 'category', 'description']]
merged_df.fillna('', inplace=True)
merged_df
# Out:
#       store_id                                       product_name  quantity  \
# 1           45                                       Joghurt mild        18
# 2           82                           Saatenliebe Mohn Avocado         3
# 3           64                  Linsen-Aufstrich Rote Linse Chili        18
# 4           59                                      Dinkel Flakes         2
# 5           36                                     Basis Porridge         0
# 6            8                                         Backpulver         7
# 7           81                       Bio-Aufstrich Paprika pikant         1
# 8           48              Alnatura Leinsamen pflaume und dattel         1
# 9           20                               Leinsamen geschrotet        18
# 10          78                              Leinsamen, Geschrotet        19
# 11          84                                          Bolognese         7
# ...
